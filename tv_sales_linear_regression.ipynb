# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('SLR_TvMarketing.csv')
df
# Out:
#         TV  Sales
# 0    230.1   22.1
# 1     44.5   10.4
# 2     17.2    9.3
# 3    151.5   18.5
# 4    180.8   12.9
# ..     ...    ...
# 195   38.2    7.6
# 196   94.2    9.7
# 197  177.0   12.8
# 198  283.6   25.5
# 199  232.1   13.4
#
# [200 rows x 2 columns]

# %%
df.shape
# Out:
# (200, 2)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of         TV  Sales
# 0    230.1   22.1
# 1     44.5   10.4
# 2     17.2    9.3
# 3    151.5   18.5
# 4    180.8   12.9
# ..     ...    ...
# 195   38.2    7.6
# 196   94.2    9.7
# 197  177.0   12.8
# 198  283.6   25.5
# 199  232.1   13.4
#
# [200 rows x 2 columns]>

# %%
df.isnull().sum()
# Out:
# TV       0
# Sales    0
# dtype: int64

# %%
x,y=df[['TV']],df[['Sales']]

# %%
x_test,x_train,y_test,y_train=train_test_split(x,y,test_size=0.2)

# %%
print(x_test.shape,x_train.shape,y_test.shape,y_train.shape)
# Out:
# (160, 1) (40, 1) (160, 1) (40, 1)

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)

# %%
type(y_test)
# Out:
# pandas.core.frame.DataFrame

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 2.855825882130444

# %%
y_test_new = y_test.head(10)
y_pred_new = y_pred[:10]
y_pred_new
# Out:
# array([[ 6.70096169],
#        [14.624329  ],
#        [19.48438701],
#        [15.07793441],
#        [20.89822206],
#        [22.1471097 ],
#        [18.04109705],
#        [24.1205878 ],
#        [14.86585915],
#        [15.48441199]])

# %%
plt.plot(range(0,len(y_test_new)),y_test_new,c='b')
plt.plot(range(0,len(y_test_new)),y_pred_new,c='r')
